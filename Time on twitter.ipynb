# %%
from pylab import *
# %matplotlib inline
xkcd()

# %%
fig, axes = plt.subplots(2, 1, sharex=True, sharey=True, figsize=[5, 6])
axes = axes.flatten()

for ax in axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
#axes[0].set_title('Hockey')
#axes[1].set_title('Twitter')
axes[0].set_xlabel('Time on ice')
axes[0].set_ylabel('QualTeam')
axes[1].set_xlabel('Time on twitter')
axes[1].set_ylabel('QualTweet')

axes[0].plot([0, 1], [0, 1])
axes[0].set_xticks([])
axes[0].set_yticks([])

axes[1].plot([0, 1], [1, 0])
axes[1].set_xticks([])
axes[1].set_yticks([])

fig.tight_layout()
