# %%
from pylab import *
# %matplotlib inline
import matplotlib.cm as mcm

# %%
xkcd()
rcParams['font.size']=20
fig = gcf()
ax = gca()
xticks([]) # labels
yticks([])
ax.xaxis.set_ticks_position('none') # tick markers
ax.yaxis.set_ticks_position('none')
for side in ['bottom','right','top','left']:
    ax.spines[side].set_visible(False)
    
dps = fig.dpi_scale_trans.inverted()
bbox = ax.get_window_extent().transformed(dps)
width, height = bbox.width, bbox.height

# manual arrowhead width and length
hw = 1./20
hl = 1./20
lw = 1. # axis line width
ohg = 0.3 # arrow overhang

# compute matching arrowhead length and width
yhw = hw * height/width
yhl = hl * width/height

# draw x and y axis
ax.arrow(0, 0, 1, 0., fc='k', ec='k', lw = lw,
         head_width=hw, head_length=hl, overhang = ohg,
         length_includes_head= True, clip_on = False)

ax.arrow(0, 0, 0., 1, fc='k', ec='k', lw = lw,
         head_width=yhw, head_length=yhl, overhang = ohg,
         length_includes_head= True, clip_on = False)

clip_on = True #if only positive x or y values.

xlim(0, 1)
ylim(0, 1)

from scipy.stats import norm

mu = 0.6
sigma = 0.2
x = arange(0, 1, 0.01)
y = norm.pdf(x, mu, sigma)/2
plot(x, y, label = 'Great team')
fill_between(x, y, where = y > 0, color = 'b', alpha = 0.5)

mu = 0.4
sigma = 0.2
x = arange(0, 1, 0.01)
y = norm.pdf(x, mu, sigma)/2
plot(x, y, label = 'Average team')
fill_between(x, y, where = y > 0, color = 'r', alpha = 0.5)

annotate('Avg beats\ngreat\nsometimes', xy=(0.5, 0.3), va='center', ha='center')

xlabel('Quality of play')
ylabel('Density')
title('Parity')
legend(loc=2, bbox_to_anchor=(1, 1), fontsize = 12)

# %%
help(norm.pdf)
# Out:
# Help on method pdf in module scipy.stats._distn_infrastructure:
#
# pdf(x, *args, **kwds) method of scipy.stats._continuous_distns.norm_gen instance
#     Probability density function at x of the given RV.
#
#     Parameters
#     ----------
#     x : array_like
#         quantiles
#     arg1, arg2, arg3,... : array_like
#         The shape parameter(s) for the distribution (see docstring of the
#         instance object for more information)
#     loc : array_like, optional
#         location parameter (default=0)
#     scale : array_like, optional
#         scale parameter (default=1)
#
#     Returns
#     -------
#     pdf : ndarray
#         Probability density function evaluated at x
